# %%
# !pip install -r requirements.txt

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="<ROBOFLOW_API_KEY>")
project = rf.workspace("12345678-i0yth").project("tree-relit")
dataset = project.version(6).download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="$PWD/Tree-6/data.yaml" imgsz=640 epochs=10 batch=8 plots=True name=lilium

# %%
# !yolo export model="<PATH_TO/best.pt>" format=tflite
