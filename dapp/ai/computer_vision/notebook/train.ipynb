# %%
# !pip install -U ultralytics
# Out:
# ...
#      |████████████████████████████████| 614 kB 2.8 MB/s eta 0:00:01
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.171
#     Uninstalling ultralytics-8.0.171:
#       Successfully uninstalled ultralytics-8.0.171
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/home/henriquemarlon/Downloads/verifier/dapp/ai/computer_vision/bin/python -m pip install --upgrade pip' command.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="<ROBOFLOW_API_KEY>")
project = rf.workspace("12345678-i0yth").project("tree-relit")
dataset = project.version(6).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       2 rf = Roboflow(api_key="c01zukD0xIYDXUmqxYB2")
#       3 project = rf.workspace("12345678-i0yth").project("tree-relit")
# ----> 4 dataset = project.version(6).download("yolov8m")
#
# File ~/Downloads/verifier/dapp/ai/computer_vision/lib/python3.10/site-packages/roboflow/core/version.py:196, in Version.download(self, model_format, location, overwrite)
#     193 model_format = self.__get_format_identifier(model_format)
#     195 if model_format not in self.exports:
# --> 196     self.export(model_format)
#     198 # if model_format is not in
#     200 if location is None:
#
# File ~/Downloads/verifier/dapp/ai/computer_vision/lib/python3.10/site-packages/roboflow/core/version.py:245, in Version.export(self, model_format)
# ...

# %%
# !yolo task=<"PATH_TO_/Tree-6/data.yaml"> imgsz=640 epochs=30 batch=8 plots=True name=<"PROJECT_NAME"> # PROJECT_NAME: EX:. tree-detection
# Out:
# Ultralytics YOLOv8.0.172 🚀 Python-3.10.2 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
# ...

# %%
# !yolo export model=<"PATH_TO_/weights/best.pt"> format=tflite
# Out:
# Ultralytics YOLOv8.0.172 🚀 Python-3.10.2 torch-2.0.1+cu117 CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# PyTorch: starting from '/home/henriquemarlon/.asdf/runs/detect/tree-detection123/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (11.9 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.13.0...
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.33...
# ONNX: export success ✅ 2.2s, saved as '/home/henriquemarlon/.asdf/runs/detect/tree-detection123/weights/best.onnx' (11.6 MB)
# ...

# %%
# !yolo task=detect mode=predict model=<"PATH_TO_/best_float32.tflite"> conf=0.5 source=<"TEST_IMAGE"> save=True
# !yolo task=detect mode=predict model=/home/henriquemarlon/Downloads/verifier/dapp/ai/computer_vision/model/best_float32_v1.tflite conf=0.5 source=/home/henriquemarlon/Downloads/verifier/dapp/ai/computer_vision/Tree-6/test/images save=True
# Out:
# Ultralytics YOLOv8.0.172 🚀 Python-3.10.2 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
# Loading /home/henriquemarlon/Downloads/verifier/dapp/ai/computer_vision/model/best_float32_v1.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# image 1/5 /home/henriquemarlon/Downloads/verifier/dapp/ai/computer_vision/Tree-6/test/images/FT150_IMG_20230309_125954_LEFT_jpg.rf.90d67267f10453a3ff9d31510b9a2b13.jpg: 640x640 1 tree, 340.7ms
# image 2/5 /home/henriquemarlon/Downloads/verifier/dapp/ai/computer_vision/Tree-6/test/images/GOPR0051_JPG.rf.d0c8b2b463715b5b01a0e85c351bd4c8.jpg: 640x640 2 trees, 317.3ms
# image 3/5 /home/henriquemarlon/Downloads/verifier/dapp/ai/computer_vision/Tree-6/test/images/T09_IMG_20230531_120923_RIGHT_jpg.rf.73218ad9e8a1865ed3b8737c4dea210d.jpg: 640x640 3 trees, 317.4ms
# ...
